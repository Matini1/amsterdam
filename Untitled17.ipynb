# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# C:\Users\ajayi\AppData\Local\Temp\ipykernel_19872\1800102945.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data= pd.read_csv('HousingPrices-Amsterdam-August-2021.csv')
# Drop column 'Unnamed: 0'
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#                                     Address      Zip     Price  Area  Room  \
# 0              Blasiusstraat 8 2, Amsterdam  1091 CR  685000.0    64     3
# 1    Kromme Leimuidenstraat 13 H, Amsterdam  1059 EL  475000.0    60     3
# 2                Zaaiersweg 11 A, Amsterdam  1097 SM  850000.0   109     4
# 3              Tenerifestraat 40, Amsterdam  1060 TH  580000.0   128     6
# 4                Winterjanpad 21, Amsterdam  1036 KN  720000.0   138     5
# ..                                      ...      ...       ...   ...   ...
# 919                     Ringdijk, Amsterdam  1097 AE  750000.0   117     1
# 920         Kleine Beerstraat 31, Amsterdam  1033 CP  350000.0    72     3
# 921       Stuyvesantstraat 33 II, Amsterdam  1058 AK  350000.0    51     3
# 922   John Blankensteinstraat 51, Amsterdam  1095 MB  599000.0   113     4
# 923      S. F. van Ossstraat 334, Amsterdam  1068 JS  300000.0    79     4
#
#           Lon        Lat
# 0    4.907736  52.356157
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
# import xgboost as xgb

# %%
data = pd.read_csv('HousingPrices-Amsterdam-August-2021.csv')
data.head()
# Out:
#    Unnamed: 0                                 Address      Zip     Price  \
# 0           1            Blasiusstraat 8 2, Amsterdam  1091 CR  685000.0
# 1           2  Kromme Leimuidenstraat 13 H, Amsterdam  1059 EL  475000.0
# 2           3              Zaaiersweg 11 A, Amsterdam  1097 SM  850000.0
# 3           4            Tenerifestraat 40, Amsterdam  1060 TH  580000.0
# 4           5              Winterjanpad 21, Amsterdam  1036 KN  720000.0
#
#    Area  Room       Lon        Lat
# 0    64     3  4.907736  52.356157
# 1    60     3  4.850476  52.348586
# 2   109     4  4.944774  52.343782
# 3   128     6  4.789928  52.343712
# 4   138     5  4.902503  52.410538

# %%
plt.figure(figsize = (18, 4))
sns.heatmap(data.corr(), annot = True)
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Address  924 non-null    object
#  1   Zip      924 non-null    object
#  2   Price    920 non-null    float64
#  3   Area     924 non-null    int64
#  4   Room     924 non-null    int64
#  5   Lon      924 non-null    float64
#  6   Lat      924 non-null    float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 50.7+ KB

# %%
data.describe()
# Out:
#               Price        Area        Room         Lon         Lat
# count  9.200000e+02  924.000000  924.000000  924.000000  924.000000
# mean   6.220654e+05   95.952381    3.571429    4.888605   52.363326
# std    5.389942e+05   57.447436    1.592332    0.053140    0.024028
# min    1.750000e+05   21.000000    1.000000    4.644819   52.291519
# 25%    3.500000e+05   60.750000    3.000000    4.855834   52.352077
# 50%    4.670000e+05   83.000000    3.000000    4.886818   52.364631
# 75%    7.000000e+05  113.000000    4.000000    4.922337   52.377598
# max    5.950000e+06  623.000000   14.000000    5.029122   52.423805

# %%
data.isna().sum()
# Out:
# Address    0
# Zip        0
# Price      4
# Area       0
# Room       0
# Lon        0
# Lat        0
# dtype: int64

# %%
for m in data.columns:
    print(m)
# Out:
# Address
# Zip
# Price
# Area
# Room
# Lon
# Lat

# %%
num = data.select_dtypes(include = 'number')
cat = data.select_dtypes(exclude = 'number')

print(f'\t\tCategorical Data')
display(cat.head())
print(f'\n\n\t\tNumerical Data')
display(num.head())
# Out:
# 		Categorical Data
#                                   Address      Zip
# 0            Blasiusstraat 8 2, Amsterdam  1091 CR
# 1  Kromme Leimuidenstraat 13 H, Amsterdam  1059 EL
# 2              Zaaiersweg 11 A, Amsterdam  1097 SM
# 3            Tenerifestraat 40, Amsterdam  1060 TH
# 4              Winterjanpad 21, Amsterdam  1036 KN
# 		Numerical Data
#       Price  Area  Room       Lon        Lat
# 0  685000.0    64     3  4.907736  52.356157
# 1  475000.0    60     3  4.850476  52.348586
# 2  850000.0   109     4  4.944774  52.343782
# 3  580000.0   128     6  4.789928  52.343712
# 4  720000.0   138     5  4.902503  52.410538

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Function to plot scatter plots
def plotter(data, a, b):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=a, y='Price', data=data)
    plt.title(f'Scatter plot between Price and {a}')
    plt.xlabel(a)
    plt.ylabel('Price')
    plt.show()

# Load the data
data = pd.read_csv('HousingPrices-Amsterdam-August-2021.csv')

# Suppress warnings
warnings.filterwarnings('ignore')

# Plotting different combinations
plotter(data, 'Price', 'Address')
plotter(data, 'Area', 'Room')
plotter(data, 'Lat', 'Lon')
plotter(data, 'Zip', 'Unnamed: 0')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame
data = pd.read_csv('HousingPrices-Amsterdam-August-2021.csv')

# Call the plotter function with the desired columns
plotter(data, 'Room', 'Zip')
plotter(data, 'Address', 'Price')
plotter(data, 'Lon', 'Area')
plotter(data, 'lat', 'price')

# Show the plots
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 12
#      10 plotter(data, 'Address', 'Price')
#      11 plotter(data, 'Lon', 'Area')
# ---> 12 plotter(data, 'lat', 'price')
#      14 # Show the plots
#      15 plt.show()
#
# Cell In[14], line 9, in plotter(data, a, b)
#       7 def plotter(data, a, b):
#       8     plt.figure(figsize=(10, 6))
# ----> 9     sns.scatterplot(x=a, y='Price', data=data)
#      10     plt.title(f'Scatter plot between Price and {a}')
#      11     plt.xlabel(a)
#
# File c:\Users\ajayi\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
# ...

# %%
x = data.drop('Price', axis = 1)
y = data.Price


from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=2, random_state=4)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# Drop non-numeric columns for now
xtrain_numeric = xtrain.drop(['Address'], axis=1)
xtest_numeric = xtest.drop(['Address'], axis=1)

# Combine train and test data for encoding
combined_data = pd.concat([xtrain_numeric, xtest_numeric], ignore_index=True)

# Use LabelEncoder for 'Zip' column
label_encoder = LabelEncoder()
combined_data['Zip'] = label_encoder.fit_transform(combined_data['Zip'])

# One-hot encode other categorical columns if needed
# For example, if 'Room' is categorical:
# combined_data = pd.get_dummies(combined_data, columns=['Room'])

# Split back into train and test
xtrain_encoded = combined_data[:len(xtrain_numeric)]
xtest_encoded = combined_data[len(xtrain_numeric):]

# Handle missing values
imputer = SimpleImputer(strategy='median')
xtrain_imputed = imputer.fit_transform(xtrain_encoded)
xtest_imputed = imputer.transform(xtest_encoded)

# Check if there are any missing values in ytrain
missing_ytrain = ytrain.isnull().sum()
if missing_ytrain > 0:
    # Fill missing values with median
    ytrain = ytrain.fillna(ytrain.median())

# Initialize the RandomForestRegressor
rf_regressor = RandomForestRegressor()

# Train the model
rf_regressor.fit(xtrain_imputed, ytrain)
validation = rf_regressor.predict(xtrain_imputed)
print("R2 Score on Training Data:", r2_score(ytrain, validation) * 100)

# Evaluate on test data
test_predictions = rf_regressor.predict(xtest_imputed)
print("R2 Score on Test Data:", r2_score(ytest, test_predictions) * 100)
# Out:
# R2 Score on Training Data: 95.80039886255183
# R2 Score on Test Data: 96.99458516897506

# %%
# Export the model
import pickle
pickle.dump(rf_regressor, open('/content/HousingPrices-Amsterdam-August-2021.pkl', "wb"))
